# %%
import pandas as pd
import numpy as np
import random
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
le = LabelEncoder()

# %%
crx = pd.read_csv(r"C:\Users\chy0103\Desktop\workspace\MachineLearning-2022\hw1\crx.csv")
data = pd.read_csv(r"C:\Users\chy0103\Desktop\workspace\MachineLearning-2022\hw1\data.csv")

# %%
crx
# Out:
#     att1   att2    att3 att4 att5 att6 att7  att8 att9 att10  att11 att12  \
# 0      b  30.83   0.000    u    g    w    v  1.25    t     t      1     f
# 1      a  58.67   4.460    u    g    q    h  3.04    t     t      6     f
# 2      a   24.5   0.500    u    g    q    h  1.50    t     f      0     f
# 3      b  27.83   1.540    u    g    w    v  3.75    t     t      5     t
# 4      b  20.17   5.625    u    g    w    v  1.71    t     f      0     f
# ..   ...    ...     ...  ...  ...  ...  ...   ...  ...   ...    ...   ...
# 685    b  21.08  10.085    y    p    e    h  1.25    f     f      0     f
# 686    a  22.67   0.750    u    g    c    v  2.00    f     t      2     t
# 687    a  25.25  13.500    y    p   ff   ff  2.00    f     t      1     t
# 688    b  17.92   0.205    u    g   aa    v  0.04    f     f      0     f
# 689    b     35   3.375    u    g    c    h  8.29    f     f      0     t
#
#     att13 att14  att15 label
# 0       g   202      0     +
# 1       g    43    560     +
# 2       g   280    824     +
# 3       g   100      3     +
# 4       s   120      0     +
# ..    ...   ...    ...   ...
# 685     g   260      0     -
# 686     g   200    394     -
# 687     g   200      1     -
# 688     g   280    750     -
# 689     g     0      0     -
#
# [690 rows x 16 columns]

# %%
# remove ? in att2 and att14
crx = crx.drop(crx[crx["att2"]=="?"].index)
crx = crx.drop(crx[crx["att14"]=="?"].index)
crx = crx.reset_index(drop=True)
crx
# Out:
#     att1   att2    att3 att4 att5 att6 att7  att8 att9 att10  att11 att12  \
# 0      b  30.83   0.000    u    g    w    v  1.25    t     t      1     f
# 1      a  58.67   4.460    u    g    q    h  3.04    t     t      6     f
# 2      a   24.5   0.500    u    g    q    h  1.50    t     f      0     f
# 3      b  27.83   1.540    u    g    w    v  3.75    t     t      5     t
# 4      b  20.17   5.625    u    g    w    v  1.71    t     f      0     f
# ..   ...    ...     ...  ...  ...  ...  ...   ...  ...   ...    ...   ...
# 661    b  21.08  10.085    y    p    e    h  1.25    f     f      0     f
# 662    a  22.67   0.750    u    g    c    v  2.00    f     t      2     t
# 663    a  25.25  13.500    y    p   ff   ff  2.00    f     t      1     t
# 664    b  17.92   0.205    u    g   aa    v  0.04    f     f      0     f
# 665    b     35   3.375    u    g    c    h  8.29    f     f      0     t
#
#     att13 att14  att15 label
# 0       g   202      0     +
# 1       g    43    560     +
# 2       g   280    824     +
# 3       g   100      3     +
# 4       s   120      0     +
# ..    ...   ...    ...   ...
# 661     g   260      0     -
# 662     g   200    394     -
# 663     g   200      1     -
# 664     g   280    750     -
# 665     g     0      0     -
#
# [666 rows x 16 columns]

# %%
crx["label"] = crx["label"].apply(lambda x:1 if x == "+" else -1)

# %%
# use label encoding on discrete feature
for col in ["att1","att4","att5","att6","att7","att9","att10","att12","att13"]:
    crx[col] = le.fit_transform(crx[col])
crx_label = crx["label"]
crx = crx.drop("label",axis=1)
crx["att2"],crx["att14"] = pd.to_numeric(crx["att2"]),pd.to_numeric(crx["att14"])
crx
# Out:
#      att1   att2    att3  att4  att5  att6  att7  att8  att9  att10  att11  \
# 0       2  30.83   0.000     1     0    13     8  1.25     1      1      1
# 1       1  58.67   4.460     1     0    11     4  3.04     1      1      6
# 2       1  24.50   0.500     1     0    11     4  1.50     1      0      0
# 3       2  27.83   1.540     1     0    13     8  3.75     1      1      5
# 4       2  20.17   5.625     1     0    13     8  1.71     1      0      0
# ..    ...    ...     ...   ...   ...   ...   ...   ...   ...    ...    ...
# 661     2  21.08  10.085     2     2     5     4  1.25     0      0      0
# 662     1  22.67   0.750     1     0     2     8  2.00     0      1      2
# 663     1  25.25  13.500     2     2     6     3  2.00     0      1      1
# 664     2  17.92   0.205     1     0     1     8  0.04     0      0      0
# 665     2  35.00   3.375     1     0     2     4  8.29     0      0      0
#
#      att12  att13  att14  att15
# 0        0      0    202      0
# 1        0      0     43    560
# 2        0      0    280    824
# 3        1      0    100      3
# 4        0      2    120      0
# ..     ...    ...    ...    ...
# 661      0      0    260      0
# 662      1      0    200    394
# 663      1      0    200      1
# 664      0      0    280    750
# 665      1      0      0      0
#
# [666 rows x 15 columns]

# %%
# Normalization
def normalize(data):
    for i in data.columns:
        mean = data[i].mean()
        std = data[i].std()
        data[i] = (data[i] - mean)/std
    return data

# %%
norm_crx = normalize(crx)
norm_crx
# Out:
#          att1      att2      att3      att4      att5      att6      att7  \
# 0    0.667039 -0.062000 -0.958598 -0.538994 -0.556124  1.453436  0.768080
# 1   -1.290000  2.273536 -0.067544 -0.538994 -0.556124  0.989284 -0.814414
# 2   -1.290000 -0.593033 -0.858704 -0.538994 -0.556124  0.989284 -0.814414
# 3    0.667039 -0.313674 -0.650924 -0.538994 -0.556124  1.453436  0.768080
# 4    0.667039 -0.956282  0.165209 -0.538994 -0.556124  1.453436  0.768080
# ..        ...       ...       ...       ...       ...       ...       ...
# 661  0.667039 -0.879941  1.056263  1.791979  1.802974 -0.403171 -0.814414
# 662 -1.290000 -0.746554 -0.808757 -0.538994 -0.556124 -1.099398  0.768080
# 663 -1.290000 -0.530114  1.738538  1.791979  1.802974 -0.171095 -1.210037
# 664  0.667039 -1.145038 -0.917641 -0.538994 -0.556124 -1.331474  0.768080
# 665  0.667039  0.287827 -0.284314 -0.538994 -0.556124 -1.099398 -0.814414
#
#          att8      att9     att10     att11     att12     att13     att14  \
# 0   -0.290453  0.943772  1.137807 -0.296049 -0.924050 -0.304250  0.115959
# 1    0.244259  0.943772  1.137807  0.718192 -0.924050 -0.304250 -0.811274
# 2   -0.215772  0.943772 -0.877564 -0.498897 -0.924050 -0.304250  0.570828
# 3    0.456351  0.943772  1.137807  0.515344  1.080567 -0.304250 -0.478870
# 4   -0.153041  0.943772 -0.877564 -0.498897 -0.924050  3.314147 -0.362237
# ..        ...       ...       ...       ...       ...       ...       ...
# 661 -0.290453 -1.057987 -0.877564 -0.498897 -0.924050 -0.304250  0.454195
# 662 -0.066412 -1.057987  1.137807 -0.093201  1.080567 -0.304250  0.104296
# 663 -0.066412 -1.057987  1.137807 -0.296049  1.080567 -0.304250  0.104296
# 664 -0.651906 -1.057987 -0.877564 -0.498897 -0.924050 -0.304250  0.570828
# 665  1.812547 -1.057987 -0.877564 -0.498897  1.080567 -0.304250 -1.062035
#
#         att15
# 0   -0.191926
# 1   -0.084295
# 2   -0.033555
# 3   -0.191349
# 4   -0.191926
# ..        ...
# 661 -0.191926
# 662 -0.116200
# 663 -0.191733
# 664 -0.047777
# 665 -0.191926
#
# [666 rows x 15 columns]

# %%
data
# Out:
#            ID Diagnosis      3      4       5       6        7        8  \
# 0      842302         M  17.99  10.38  122.80  1001.0  0.11840  0.27760
# 1      842517         M  20.57  17.77  132.90  1326.0  0.08474  0.07864
# 2    84300903         M  19.69  21.25  130.00  1203.0  0.10960  0.15990
# 3    84348301         M  11.42  20.38   77.58   386.1  0.14250  0.28390
# 4    84358402         M  20.29  14.34  135.10  1297.0  0.10030  0.13280
# ..        ...       ...    ...    ...     ...     ...      ...      ...
# 564    926424         M  21.56  22.39  142.00  1479.0  0.11100  0.11590
# 565    926682         M  20.13  28.25  131.20  1261.0  0.09780  0.10340
# 566    926954         M  16.60  28.08  108.30   858.1  0.08455  0.10230
# 567    927241         M  20.60  29.33  140.10  1265.0  0.11780  0.27700
# 568     92751         B   7.76  24.54   47.92   181.0  0.05263  0.04362
#
#            9       10  ...      23     24      25      26       27       28  \
# 0    0.30010  0.14710  ...  25.380  17.33  184.60  2019.0  0.16220  0.66560
# 1    0.08690  0.07017  ...  24.990  23.41  158.80  1956.0  0.12380  0.18660
# 2    0.19740  0.12790  ...  23.570  25.53  152.50  1709.0  0.14440  0.42450
# 3    0.24140  0.10520  ...  14.910  26.50   98.87   567.7  0.20980  0.86630
# 4    0.19800  0.10430  ...  22.540  16.67  152.20  1575.0  0.13740  0.20500
# ..       ...      ...  ...     ...    ...     ...     ...      ...      ...
# 564  0.24390  0.13890  ...  25.450  26.40  166.10  2027.0  0.14100  0.21130
# 565  0.14400  0.09791  ...  23.690  38.25  155.00  1731.0  0.11660  0.19220
# 566  0.09251  0.05302  ...  18.980  34.12  126.70  1124.0  0.11390  0.30940
# 567  0.35140  0.15200  ...  25.740  39.42  184.60  1821.0  0.16500  0.86810
# 568  0.00000  0.00000  ...   9.456  30.37   59.16   268.6  0.08996  0.06444
#
#          29      30      31  Unnamed: 31
# 0    0.7119  0.2654  0.4601      0.11890
# 1    0.2416  0.1860  0.2750      0.08902
# 2    0.4504  0.2430  0.3613      0.08758
# 3    0.6869  0.2575  0.6638      0.17300
# 4    0.4000  0.1625  0.2364      0.07678
# ..      ...     ...     ...          ...
# 564  0.4107  0.2216  0.2060      0.07115
# 565  0.3215  0.1628  0.2572      0.06637
# 566  0.3403  0.1418  0.2218      0.07820
# 567  0.9387  0.2650  0.4087      0.12400
# 568  0.0000  0.0000  0.2871      0.07039
#
# [569 rows x 32 columns]

# %%
data = data.rename(columns={'Diagnosis':'label'})
data["label"] = data["label"].apply(lambda x:1 if x == "M" else -1)
data_label = data["label"]
data = data.drop("ID",axis=1)

# %%
data
# Out:
#      label      3      4       5       6        7        8        9       10  \
# 0        1  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.30010  0.14710
# 1        1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.08690  0.07017
# 2        1  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.19740  0.12790
# 3        1  11.42  20.38   77.58   386.1  0.14250  0.28390  0.24140  0.10520
# 4        1  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.19800  0.10430
# ..     ...    ...    ...     ...     ...      ...      ...      ...      ...
# 564      1  21.56  22.39  142.00  1479.0  0.11100  0.11590  0.24390  0.13890
# 565      1  20.13  28.25  131.20  1261.0  0.09780  0.10340  0.14400  0.09791
# 566      1  16.60  28.08  108.30   858.1  0.08455  0.10230  0.09251  0.05302
# 567      1  20.60  29.33  140.10  1265.0  0.11780  0.27700  0.35140  0.15200
# 568     -1   7.76  24.54   47.92   181.0  0.05263  0.04362  0.00000  0.00000
#
#          11  ...      23     24      25      26       27       28      29  \
# 0    0.2419  ...  25.380  17.33  184.60  2019.0  0.16220  0.66560  0.7119
# 1    0.1812  ...  24.990  23.41  158.80  1956.0  0.12380  0.18660  0.2416
# 2    0.2069  ...  23.570  25.53  152.50  1709.0  0.14440  0.42450  0.4504
# 3    0.2597  ...  14.910  26.50   98.87   567.7  0.20980  0.86630  0.6869
# 4    0.1809  ...  22.540  16.67  152.20  1575.0  0.13740  0.20500  0.4000
# ..      ...  ...     ...    ...     ...     ...      ...      ...     ...
# 564  0.1726  ...  25.450  26.40  166.10  2027.0  0.14100  0.21130  0.4107
# 565  0.1752  ...  23.690  38.25  155.00  1731.0  0.11660  0.19220  0.3215
# 566  0.1590  ...  18.980  34.12  126.70  1124.0  0.11390  0.30940  0.3403
# 567  0.2397  ...  25.740  39.42  184.60  1821.0  0.16500  0.86810  0.9387
# 568  0.1587  ...   9.456  30.37   59.16   268.6  0.08996  0.06444  0.0000
#
#          30      31  Unnamed: 31
# 0    0.2654  0.4601      0.11890
# 1    0.1860  0.2750      0.08902
# 2    0.2430  0.3613      0.08758
# 3    0.2575  0.6638      0.17300
# 4    0.1625  0.2364      0.07678
# ..      ...     ...          ...
# 564  0.2216  0.2060      0.07115
# 565  0.1628  0.2572      0.06637
# 566  0.1418  0.2218      0.07820
# 567  0.2650  0.4087      0.12400
# 568  0.0000  0.2871      0.07039
#
# [569 rows x 31 columns]

# %%
data = data.drop("label",axis=1)
norm_data = normalize(data)
norm_data
# Out:
#             3         4         5         6         7         8         9  \
# 0    1.096100 -2.071512  1.268817  0.983510  1.567087  3.280628  2.650542
# 1    1.828212 -0.353322  1.684473  1.907030 -0.826235 -0.486643 -0.023825
# 2    1.578499  0.455786  1.565126  1.557513  0.941382  1.052000  1.362280
# 3   -0.768233  0.253509 -0.592166 -0.763792  3.280667  3.399917  1.914213
# 4    1.748758 -1.150804  1.775011  1.824624  0.280125  0.538866  1.369806
# ..        ...       ...       ...       ...       ...       ...       ...
# 564  2.109139  0.720838  2.058974  2.341795  1.040926  0.218868  1.945573
# 565  1.703356  2.083301  1.614511  1.722326  0.102368 -0.017817  0.692434
# 566  0.701667  2.043775  0.672084  0.577445 -0.839745 -0.038646  0.046547
# 567  1.836725  2.334403  1.980781  1.733693  1.524426  3.269267  3.294046
# 568 -1.806811  1.220718 -1.812793 -1.346604 -3.109349 -1.149741 -1.113893
#
#            10        11        12  ...        23        24        25  \
# 0    2.530249  2.215566  2.253764  ...  1.885031 -1.358098  2.301575
# 1    0.547662  0.001391 -0.867889  ...  1.804340 -0.368879  1.533776
# 2    2.035440  0.938859 -0.397658  ...  1.510541 -0.023953  1.346291
# 3    1.450431  2.864862  4.906602  ... -0.281217  0.133866 -0.249720
# 4    1.427237 -0.009552 -0.561956  ...  1.297434 -1.465481  1.337363
# ..        ...       ...       ...  ...       ...       ...       ...
# 564  2.318924 -0.312314 -0.930209  ...  1.899514  0.117596  1.751022
# 565  1.262558 -0.217473 -1.057681  ...  1.535369  2.045599  1.420690
# 566  0.105684 -0.808406 -0.894800  ...  0.560868  1.373645  0.578492
# 567  2.656528  2.135315  1.042778  ...  1.959515  2.235958  2.301575
# 568 -1.260710 -0.819349 -0.560539  ... -1.409652  0.763518 -1.431475
#
#            26        27        28        29        30        31  Unnamed: 31
# 0    1.999478  1.306537  2.614365  2.107672  2.294058  2.748204     1.935312
# 1    1.888827 -0.375282 -0.430066 -0.146620  1.086129 -0.243675     0.280943
# 2    1.455004  0.526944  1.081980  0.854222  1.953282  1.151242     0.201214
# 3   -0.549538  3.391291  3.889975  1.987839  2.173873  6.040726     4.930672
# 4    1.219651  0.220362 -0.313119  0.612640  0.728618 -0.867590    -0.396751
# ..        ...       ...       ...       ...       ...       ...          ...
# 564  2.013529  0.378033 -0.273077  0.663928  1.627719 -1.358963    -0.708467
# 565  1.493644 -0.690623 -0.394473  0.236365  0.733182 -0.531387    -0.973122
# 566  0.427529 -0.808876  0.350427  0.326479  0.413705 -1.103578    -0.318129
# 567  1.651717  1.429169  3.901415  3.194794  2.287972  1.917396     2.217684
# 568 -1.074867 -1.857384 -1.206491 -1.304683 -1.743529 -0.048096    -0.750546
#
# [569 rows x 30 columns]

# %%
crx_x_train,crx_x_test,crx_y_train,crx_y_test = train_test_split(norm_crx,crx_label,test_size=0.2,random_state=1024)
data_x_train,data_x_test,data_y_train,data_y_test = train_test_split(norm_data,data_label,test_size=0.2,random_state=1024)

# %%
# initialize crx weights
weights_crx = np.random.randn(len(norm_crx.columns))
constant_crx = random.random()
lr = 0.001
max_iter = 10

# %%
# initailize data weights
weights_data = np.random.randn(len(norm_data.columns))
constant_data = random.random()
lr = 0.001
max_iter = 10

# %%
random.Random(0).shuffle(crx_x_train.index.values)
crx_x_train
# Out:
#          att1      att2      att3      att4      att5      att6      att7  \
# 211  0.667039 -0.788500  1.463830 -0.538994 -0.556124 -1.099398  0.768080
# 233 -1.290000 -1.145038  1.081236 -0.538994 -0.556124 -0.171095 -1.210037
# 339 -1.290000  0.518528  0.140235 -0.538994 -0.556124  0.989284  0.768080
# 336  0.667039  0.120044 -0.459128  1.791979  1.802974  1.453436  0.768080
# 281  0.667039  0.218197 -0.409181 -0.538994 -0.556124  0.060981 -2.001284
# ..        ...       ...       ...       ...       ...       ...       ...
# 535  0.667039  1.392676 -0.259340 -0.538994 -0.556124 -1.331474  0.768080
# 588  0.667039 -0.837996 -0.800765  1.791979  1.802974 -0.867322  0.768080
# 224  0.667039 -1.012490  0.956369 -0.538994 -0.556124 -1.331474  0.768080
# 443 -1.290000  1.210632 -0.159446 -0.538994 -0.556124  0.293057 -0.418791
# 442  0.667039  0.071387 -0.526057  1.791979  1.802974  0.525132 -1.210037
#
#          att8      att9     att10     att11     att12     att13     att14  \
# 211  0.332382 -1.057987  1.137807 -0.093201  1.080567 -0.304250 -0.012338
# 233 -0.663855 -1.057987 -0.877564 -0.498897 -0.924050 -0.304250 -1.062035
# 339 -0.626515  0.943772 -0.877564 -0.498897  1.080567 -0.304250  0.267582
# 336  1.427196 -1.057987 -0.877564 -0.498897  1.080567 -0.304250  0.570828
# 281  0.082949 -1.057987 -0.877564 -0.498897  1.080567 -0.304250  0.290909
# ..        ...       ...       ...       ...       ...       ...       ...
# 535  0.381671  0.943772 -0.877564 -0.498897 -0.924050  3.314147  0.279245
# 588 -0.465205 -1.057987 -0.877564 -0.498897 -0.924050 -0.304250 -0.128971
# 224 -0.427865 -1.057987 -0.877564 -0.498897 -0.924050 -0.304250 -0.595503
# 443 -0.663855  0.943772 -0.877564 -0.498897 -0.924050 -0.304250 -0.478870
# 442 -0.663855 -1.057987 -0.877564 -0.498897 -0.924050 -0.304250 -0.362237
#
#         att15
# 211 -0.158675
# 233 -0.182316
# 339 -0.191926
# 336 -0.191926
# 281 -0.153486
# ..        ...
# 535 -0.191926
# 588 -0.191926
# 224 -0.124656
# 443 -0.007416
# 442 -0.191926
#
# [532 rows x 15 columns]

# %% [markdown]
# # Q2:Linear classifier

# %%
# training
def linear_classifier(weight,constant,lr,max_iter,data,label,x_train,y_train):
    random.shuffle(x_train.index.values)
    for i in x_train.index:
        ind = np.random.choice(x_train.index)
        feat = np.array(data.iloc[ind,])
        pred = np.sign(np.dot(feat,weight) + constant)
        if pred < 0:
            for j in range(max_iter):
                weight = weight + lr * feat * label[ind]
                constant = constant + label[ind]
                pred = np.sign(np.dot(feat,weight) + constant)
                if pred > 0:
                    break
    return weight,constant

# %%
# testing crx data
for i in range(5):
    correct = 0
    weights,constant = linear_classifier(weights_crx,constant_crx,lr,max_iter,norm_crx,crx_label,crx_x_train,crx_y_train)
    for j in crx_x_test.index:
        feat = np.array(norm_crx.iloc[j,])
        pred = np.sign(np.dot(feat,weights) + constant)
        if pred == crx_label.iloc[j,]:
            correct += 1
    print("Linear Classifier Accuracy:{}".format(correct/len(crx_y_test)))
# Out:
# Linear Classifier Accuracy:0.41044776119402987
# Linear Classifier Accuracy:0.41044776119402987
# Linear Classifier Accuracy:0.6044776119402985
# Linear Classifier Accuracy:0.41044776119402987
# Linear Classifier Accuracy:0.41044776119402987

# %%
# testing data
for i in range(5):
    correct = 0
    weights,constant = linear_classifier(weights_data,constant_data,lr,max_iter,norm_data,data_label,data_x_train,data_y_train)
    for j in range(len(data_x_test)):
        feat = np.array(norm_data.iloc[j,])
        pred = np.sign(np.dot(feat,weights) + constant)
        if pred == data_label.iloc[j,]:
            correct += 1
    print("Linear Classifier Accuracy:{}".format(correct/len(data_y_test)))
# Out:
# Linear Classifier Accuracy:0.40350877192982454
# Linear Classifier Accuracy:0.40350877192982454
# Linear Classifier Accuracy:0.40350877192982454
# Linear Classifier Accuracy:0.40350877192982454
# Linear Classifier Accuracy:0.40350877192982454

# %% [markdown]
# # Q3:Least square method

# %%
# least square method
def least_square(x,y):
    constant = np.ones((len(x),1))
    x = np.concatenate((constant,np.matrix(x)),axis=1)
    xTx = np.matmul(x.transpose(),x)
    xTx_inv = np.linalg.inv(xTx)
    xTy = np.matmul(x.transpose(),y)
    weights = np.matmul(xTx_inv,xTy)
    return weights

# %%
# testing crx
W = least_square(crx_x_train,crx_y_train)
constant_lse = np.ones((len(crx_x_test),1))
x = np.concatenate((constant_lse,np.matrix(crx_x_test)),axis=1)
pred = np.sign((np.dot(x,W.transpose())))
correct = 0
for i in range(len(pred)):
    if pred[i] == crx_label.iloc[i]:
        correct += 1
print("Least squared method Accuracy:{}".format(correct/len(pred)))
# Out:
# Least squared method Accuracy:0.5

# %%
# testing data
W = least_square(data_x_train,data_y_train)
constant_lse = np.ones((len(data_x_test),1))
x = np.concatenate((constant_lse,np.matrix(data_x_test)),axis=1)
pred = np.sign((np.dot(x,W.transpose())))
correct = 0
for i in range(len(pred)):
    if pred[i] == data_label.iloc[i]:
        correct += 1
print("Least squared method Accuracy:{}".format(correct/len(pred)))
# Out:
# Least squared method Accuracy:0.4649122807017544

# %% [markdown]
# # Q4:Voted perceptron

# %%
def voted_perceptron(weight,constant,lr,data,label,x_train,y_train):
    random.shuffle(x_train.index.values)
    all_weight = []
    all_correct = []
    correct = 0
    for i in x_train.index:
        ind = np.random.choice(x_train.index)
        feat = np.array(data.iloc[ind,])
        pred = np.sign(np.dot(feat,weight) + constant)
        if pred > 0:
            correct += 1
        else:
            all_weight.append(weight)
            all_correct.append(correct)
            weight = weight + lr * feat * label[ind]
            constant = constant + label[ind]
            correct = 0
    return all_weight,constant,all_correct

# %%
def avg_voted_perceptron(all_weight,all_correct):
    for i in range(len(all_weight)):
        all_weight[i] = all_weight[i]*all_correct[i]
    all_weight = sum(all_weight)/sum(all_correct)
    return all_weight

# %%
# testing crx
for i in range(5):
    correct = 0
    all_weights,constant,all_correct = voted_perceptron(weights_crx,constant_crx,lr,norm_crx,crx_label,crx_x_train,crx_y_train)
    for j in crx_x_test.index:
        feat = np.array(norm_crx.iloc[j,])
        positive,negative = 0,0
        for k in range(len(all_weights)):
            pred = np.sign(np.dot(feat,all_weights[k]) + constant)
            if pred > 0:
                positive += pred * all_correct[k]
            else:
                negative += -pred * all_correct[k]
        if positive + negative > 0:
            pred = 1
        else:
            pred = -1
        if pred == crx_label.iloc[j,]:
            correct += 1
    print("Voted Perceptron Accuracy:{}".format(correct/len(crx_y_test)))
# Out:
# Voted Perceptron Accuracy:0.39552238805970147
# Voted Perceptron Accuracy:0.39552238805970147
# Voted Perceptron Accuracy:0.39552238805970147
# Voted Perceptron Accuracy:0.39552238805970147
# Voted Perceptron Accuracy:0.39552238805970147

# %%
# Average voted perceptron for crx
weights = avg_voted_perceptron(all_weights,all_correct)
correct = 0
for i in crx_x_test.index:
    feat = np.array(norm_crx.iloc[i,])
    pred = np.sign(np.dot(feat,weights) + constant)
    if pred == crx_label.iloc[i,]:
        correct += 1
print("Average voted perceptron Accuracy:{}".format(correct/len(crx_y_test)))
# Out:
# Average voted perceptron Accuracy:0.41044776119402987

# %%
# testing data
for i in range(5):
    correct = 0
    all_weights,constant,all_correct = voted_perceptron(weights_data,constant_data,lr,norm_data,data_label,data_x_train,data_y_train)
    for j in data_x_test.index:
        feat = np.array(norm_data.iloc[j,])
        positive,negative = 0,0
        for k in range(len(all_weights)):
            pred = np.sign(np.dot(feat,all_weights[k]) + constant)
            if pred > 0:
                positive += pred * all_correct[k]
            else:
                negative += -pred * all_correct[k]
        if positive + negative > 0:
            pred = 1
        else:
            pred = -1
        if pred == crx_label.iloc[j,]:
            correct += 1
    print("Voted Perceptron Accuracy:{}".format(correct/len(data_y_test)))
# Out:
# Voted Perceptron Accuracy:0.543859649122807
# Voted Perceptron Accuracy:0.543859649122807
# Voted Perceptron Accuracy:0.543859649122807
# Voted Perceptron Accuracy:0.543859649122807
# Voted Perceptron Accuracy:0.543859649122807

# %%
# Average voted perceptron for data
weights = avg_voted_perceptron(all_weights,all_correct)
correct = 0
for i in data_x_test.index:
    feat = np.array(norm_data.iloc[i,])
    pred = np.sign(np.dot(feat,weights) + constant)
    if pred == data_label.iloc[i,]:
        correct += 1
print("Average voted perceptron Accuracy:{}".format(correct/len(data_y_test)))
# Out:
# Average voted perceptron Accuracy:0.6754385964912281

# %% [markdown]
# # Q5:Maximum-margin Linear Classifier with Minimizing the ||w||^2

# %%
# compute distance
def distance(weights,observation,constant):
    dist = (np.dot(weights,observation)/np.linalg.norm(weights)) + constant
    return abs(dist)

# %%
def max_margin_linear_classifier(weight,constant,lr,data,label,x_train,y_train):
    random.shuffle(x_train.index.values)
    sampled = []
    for i in x_train.index:
        ind = np.random.choice(x_train.index)
        sampled.append(ind)
        feat = np.array(data.iloc[ind,])
        pred = np.sign(np.dot(feat,weight) + constant)
        if pred <= 0:
            weight_new = weight + lr * feat * label[ind]
            constant_new = constant + label[ind]
            for j in sampled:
                all_dist,all_dist_new = 0,0
                all_dist = all_dist +  distance(weight,feat,constant)
                all_dist_new = all_dist_new + distance(weight_new,feat,constant_new)
                if all_dist_new < all_dist:
                    weight = weight_new
                    constant = constant_new
    return weight,constant

# %%
# testing crx data
for i in range(5):
    correct = 0
    weights,constant = max_margin_linear_classifier(weights_crx,constant_crx,lr,norm_crx,crx_label,crx_x_train,crx_y_train)
    for j in crx_x_test.index:
        feat = np.array(norm_crx.iloc[j,])
        pred = np.sign(np.dot(feat,weights) + constant)
        if pred == crx_label.iloc[j,]:
            correct += 1
    print("linear classifier with the minimum w^2 Accuracy:{}".format(correct/len(crx_y_test)))
# Out:
# linear classifier with the minimum w^2 Accuracy:0.44776119402985076
# linear classifier with the minimum w^2 Accuracy:0.40298507462686567
# linear classifier with the minimum w^2 Accuracy:0.4552238805970149
# linear classifier with the minimum w^2 Accuracy:0.40298507462686567
# linear classifier with the minimum w^2 Accuracy:0.40298507462686567

# %%
# testing data
for i in range(5):
    correct = 0
    weights,constant = max_margin_linear_classifier(weights_data,constant_data,lr,norm_data,data_label,data_x_train,data_y_train)
    for j in data_x_test.index:
        feat = np.array(norm_data.iloc[j,])
        pred = np.sign(np.dot(feat,weights) + constant)
        if pred == data_label.iloc[j,]:
            correct += 1
    print("linear classifier with the minimum w^2 Accuracy:{}".format(correct/len(data_y_test)))
# Out:
# linear classifier with the minimum w^2 Accuracy:0.631578947368421
# linear classifier with the minimum w^2 Accuracy:0.6929824561403509
# linear classifier with the minimum w^2 Accuracy:0.7017543859649122
# linear classifier with the minimum w^2 Accuracy:0.6491228070175439
# linear classifier with the minimum w^2 Accuracy:0.6929824561403509

# %% [markdown]
# # Q6:Add slack variable based on Q5

# %%
def max_margin_linear_classifier_with_slack(weight,constant,lr,data,label,x_train,y_train,slack):
    random.shuffle(x_train.index.values)
    sampled = []
    for i in x_train.index:
        ind = np.random.choice(x_train.index)
        sampled.append(ind)
        feat = np.array(data.iloc[ind,])
        pred = np.sign(np.dot(feat,weight) + constant)
        if pred <= 0:
            weight_new = weight + lr * feat * label[ind]
            constant_new = constant + label[ind]
            for j in sampled:
                all_dist,all_dist_new = 0,0
                all_dist = all_dist + distance(weight,feat,constant)
                all_dist_new = all_dist_new + distance(weight_new,feat,constant_new)
                if distance(weight,data.iloc[j,],constant) > slack:
                    all_dist = all_dist + distance(weight,feat,constant) * slack
                if distance(weight_new,data.iloc[j,],constant_new) > slack:
                    all_dist_new = all_dist_new + distance(weight_new,feat,constant_new) * slack
                if all_dist_new < all_dist:
                    weight = weight_new
                    constant = constant_new
    return weight,constant

# %%
# testing crx data
slack_list = [1,3,5,7,9]
for i in slack_list:
    correct = 0
    weights,constant = max_margin_linear_classifier_with_slack(weights_crx,constant_crx,lr,norm_crx,crx_label,crx_x_train,crx_y_train,slack=i)
    for i in crx_x_test.index:
        feat = np.array(norm_crx.iloc[i,])
        pred = np.sign(np.dot(feat,weights) + constant)
        if pred == crx_label.iloc[i,]:
            correct += 1
    print("linear classifier with the minimum w^2 and slack variable Accuracy:{}".format(correct/len(crx_y_test)))
# Out:
# linear classifier with the minimum w^2 and slack variable Accuracy:0.4552238805970149
# linear classifier with the minimum w^2 and slack variable Accuracy:0.41044776119402987
# linear classifier with the minimum w^2 and slack variable Accuracy:0.3805970149253731
# linear classifier with the minimum w^2 and slack variable Accuracy:0.40298507462686567
# linear classifier with the minimum w^2 and slack variable Accuracy:0.40298507462686567

# %%
# testing data
slack_list = [1,3,5,7,9]
for i in slack_list:
    correct = 0
    weights,constant = max_margin_linear_classifier_with_slack(weights_data,constant_data,lr,norm_data,data_label,data_x_train,data_y_train,slack=i)
    for i in data_x_test.index:
        feat = np.array(norm_data.iloc[i,])
        pred = np.sign(np.dot(feat,weights) + constant)
        if pred == data_label.iloc[i,]:
            correct += 1
    print("linear classifier with the minimum w^2 and slack variable Accuracy:{}".format(correct/len(data_y_test)))
# Out:
# linear classifier with the minimum w^2 and slack variable Accuracy:0.8157894736842105
# linear classifier with the minimum w^2 and slack variable Accuracy:0.7894736842105263
# linear classifier with the minimum w^2 and slack variable Accuracy:0.7192982456140351
# linear classifier with the minimum w^2 and slack variable Accuracy:0.6228070175438597
# linear classifier with the minimum w^2 and slack variable Accuracy:0.6403508771929824

# %% [markdown]
# # Q7:Use sklearn.svm

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
svm = SVC()

# %%
def svm_result(x_train,x_test,y_train,y_test):
    svm.fit(x_train,y_train)
    pred = svm.predict(x_test)
    print("SVM Accuracy score:{}".format(accuracy_score(y_test,pred)))

# %% [markdown]
# ## For crx dataset

# %%
x_train,x_test,y_train,y_test = train_test_split(norm_crx,crx_label,test_size=0.2,random_state=1024)

# %%
svm_result(x_train,x_test,y_train,y_test)
# Out:
# SVM Accuracy score:0.8880597014925373

# %% [markdown]
# ## For data dataset

# %%
x_train,x_test,y_train,y_test = train_test_split(norm_data,data_label,test_size=0.2,random_state=1024)

# %%
svm_result(x_train,x_test,y_train,y_test)
# Out:
# SVM Accuracy score:0.9649122807017544
